# %%
#21BEC2292
#Vellore Campus
import numpy as np
import pandas as pd
# Task 1: Create a pandas DataFrame with random values
data = np.random.rand(4, 4)
columns = ['0', '1', '2', '3']
df = pd.DataFrame(data, columns=columns)
df
# Out:
#           0         1         2         3
# 0  0.675325  0.382699  0.176502  0.833510
# 1  0.567452  0.486022  0.301346  0.717315
# 2  0.403344  0.742183  0.914929  0.168930
# 3  0.174651  0.891248  0.647060  0.322576

# %%
# Task 2: Rename columns
df.rename(columns = {'0': 'Random value 1', '1': 'Random value 2', '2': 'Random value 3',
          '3': 'Random value 4'}, inplace=True)
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.675325        0.382699        0.176502        0.833510
# 1        0.567452        0.486022        0.301346        0.717315
# 2        0.403344        0.742183        0.914929        0.168930
# 3        0.174651        0.891248        0.647060        0.322576

# %%
#Task 3: Find Descriptive Statistics
descriptive_statistics = df.describe()
descriptive_statistics
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.455193        0.625538        0.509959        0.510583
# std          0.217909        0.232840        0.335415        0.315750
# min          0.174651        0.382699        0.176502        0.168930
# 25%          0.346171        0.460191        0.270135        0.284164
# 50%          0.485398        0.614102        0.474203        0.519945
# 75%          0.594420        0.779449        0.714027        0.746364
# max          0.675325        0.891248        0.914929        0.833510

# %%
# Task 4: Check for null values and find data types of columns
nullvalues = df.isnull().sum()
datatypes = df.dtypes
nullvalues
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
datatypes
# Out:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
# Task 5: Display specific columns using location and index location methods
location = df.loc[:, ['Random value 2', 'Random value 3']]
index_location = df.iloc[:, [1, 2]]
location
# Out:
#    Random value 2  Random value 3
# 0        0.382699        0.176502
# 1        0.486022        0.301346
# 2        0.742183        0.914929
# 3        0.891248        0.647060

# %%
index_location
# Out:
#    Random value 2  Random value 3
# 0        0.382699        0.176502
# 1        0.486022        0.301346
# 2        0.742183        0.914929
# 3        0.891248        0.647060
